# %% [markdown]
# # Spearman Rank Order Correlation Coefficient
#
# Clayton Miller - miller.clayton@gmail.com

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import timeit
import os
from datetime import datetime
from __future__ import division
from pylab import *
import matplotlib.dates as mdates
from matplotlib import ticker
import datetime
import matplotlib

# %%
import scipy.stats as stats

# %%
sns.set_style("whitegrid")

# %%
# %matplotlib inline

# %%
repos_path = "/Users/Clayton/temporal-features-for-buildings/"

# %%
meta = pd.read_csv(os.path.join(repos_path,"data/raw/meta_open.csv"), index_col='uid', parse_dates=["datastart","dataend"], dayfirst=True)

# %%
temp = pd.read_csv((os.path.join(repos_path,"data/interim/temp_open_utc_complete.csv")), index_col='timestamp', parse_dates=True).tz_localize('utc')

# %% [markdown]
# # Calculate Spearman Coefficient

# %%
def createspearman(temp, meta, building):
    
    timezone = meta.T[building].timezone
    start = meta.T[building].datastart
    end = meta.T[building].dataend
    building_data = pd.DataFrame(temp[building].tz_convert(timezone).truncate(before=start,after=end)).resample('D').sum().tz_localize(None)
    
    weatherfilename = meta.T[building].newweatherfilename
    
    weather = pd.read_csv(os.path.join(repos_path,"data/external/weather/"+weatherfilename),index_col='timestamp', parse_dates=True, na_values='-9999')
    weather = weather.tz_localize(timezone, ambiguous = 'infer')
    outdoor_temp = pd.DataFrame(weather[[col for col in weather.columns if 'Temperature' in col]]).resample("D").mean().tz_localize(None)
    
    combined = pd.merge(building_data, outdoor_temp, right_index=True, left_index=True, how='left')
    spearman = combined.groupby([lambda x: x.year, lambda x: x.month]).apply(lambda x: stats.spearmanr(x[building], x.ix[:,1])[0])
    
    spearman = spearman.reset_index()
    spearman.index = pd.to_datetime((spearman.level_0*100 + spearman.level_1).apply(str), format='%Y%m')
    spearman = spearman.resample('D').ffill()
    spearman = pd.DataFrame({building:spearman[0]})

    return spearman

# %%
meta[meta.T.columns.str.contains("Office")]
# Out:
#                              dataend  datastart  energystarscore  \
# uid
# Office_Elizabeth 2012-12-31 23:00:00 2012-01-01              NaN
# Office_Ellie     2012-12-31 23:00:00 2012-01-01              NaN
# Office_Cristina  2015-12-31 23:00:00 2015-01-01              NaN
# Office_Jesus     2015-11-30 23:00:00 2014-12-01              NaN
# Office_Erik      2012-12-31 23:00:00 2012-01-01              NaN
# Office_Evelyn    2012-12-31 23:00:00 2012-01-01              NaN
# Office_Emer      2012-12-31 23:00:00 2012-01-01              NaN
# Office_Elena     2012-12-31 23:00:00 2012-01-01              NaN
# Office_Jett      2015-11-30 23:00:00 2014-12-01              NaN
# Office_Jerry     2015-11-30 23:00:00 2014-12-01              NaN
# Office_Eileen    2012-12-31 23:00:00 2012-01-01              NaN
# Office_Lesa      2015-11-30 23:00:00 2014-12-01              NaN
# Office_Emerald   2012-12-31 23:00:00 2012-01-01              NaN
# Office_Ellis     2012-12-31 23:00:00 2012-01-01              NaN
# Office_Elliot    2012-12-31 23:00:00 2012-01-01              NaN
# Office_Eddie     2012-12-31 23:00:00 2012-01-01              NaN
# Office_Jackie    2015-11-30 23:00:00 2014-12-01              NaN
# Office_Marla     2015-04-30 23:00:00 2014-05-01              NaN
# Office_Maryann   2015-04-30 23:00:00 2014-05-01            100.0
# Office_Myron     2015-04-30 23:00:00 2014-05-01             87.0
# Office_Conrad    2015-12-31 23:00:00 2015-01-01              NaN
# Office_Mick      2015-04-30 23:00:00 2014-05-01             88.0
# Office_Jayden    2015-11-30 23:00:00 2014-12-01              NaN
# Office_Moises    2015-04-30 23:00:00 2014-05-01             83.0
# Office_Tod       2013-12-31 23:00:00 2013-01-01              NaN
# Office_Marcus    2015-04-30 23:00:00 2014-05-01              NaN
# Office_Bobbi     2012-12-31 23:00:00 2012-01-01              NaN
# Office_Georgia   2015-11-30 23:00:00 2014-12-01              NaN
# Office_Skyler    2015-11-30 23:00:00 2014-12-01              NaN
# Office_Marc      2015-04-30 23:00:00 2014-05-01              NaN
# ...                              ...        ...              ...
# Office_Aliyah    2015-12-31 23:00:00 2015-01-01              NaN
# Office_Curt      2015-12-31 23:00:00 2015-01-01              NaN
# Office_Glenn     2015-11-30 23:00:00 2014-12-01              NaN
# Office_Terrell   2013-12-31 23:00:00 2013-01-01              NaN
# Office_Leland    2015-11-30 23:00:00 2014-12-01              NaN
# Office_Mikayla   2015-04-30 23:00:00 2014-05-01              NaN
# Office_Ayden     2015-12-31 23:00:00 2015-01-01              NaN
# Office_Colby     2015-12-31 23:00:00 2015-01-01              NaN
# Office_Carissa   2015-12-31 23:00:00 2015-01-01              NaN
# Office_Paula     2015-12-31 23:00:00 2015-01-01              NaN
# Office_Ashanti   2015-12-31 23:00:00 2015-01-01              NaN
# Office_Garman    2015-11-30 23:00:00 2014-12-01              NaN
# Office_Cora      2015-12-31 23:00:00 2015-01-01              NaN
# Office_Mason     2015-04-30 23:00:00 2014-05-01              3.0
# Office_Clinton   2015-12-31 23:00:00 2015-01-01              NaN
# Office_Paulette  2015-12-31 23:00:00 2015-01-01              NaN
# Office_Dawn      2010-12-31 23:00:00 2010-01-01              NaN
# Office_Perla     2015-12-31 23:00:00 2015-01-01              NaN
# Office_Precious  2015-12-31 23:00:00 2015-01-01              NaN
# Office_Patricia  2015-12-31 23:00:00 2015-01-01              NaN
# Office_Pasquale  2015-12-31 23:00:00 2015-01-01              NaN
# Office_Bryon     2012-12-31 23:00:00 2012-01-01              NaN
# Office_Marcia    2015-04-30 23:00:00 2014-05-01              NaN
# Office_Dorian    2010-12-31 23:00:00 2010-01-01              NaN
# Office_Shelly    2015-11-30 23:00:00 2014-12-01              NaN
# Office_Pauline   2015-12-31 23:00:00 2015-01-01              NaN
# Office_Luann     2015-11-30 23:00:00 2014-12-01              NaN
# Office_Milton    2015-04-30 23:00:00 2014-05-01              NaN
# Office_Lane      2015-11-30 23:00:00 2014-12-01              NaN
# Office_Cameron   2015-12-31 23:00:00 2015-01-01              NaN
#
#                        heatingtype             industry mainheatingtype  \
# uid
# Office_Elizabeth               NaN  Commercial Property             NaN
# Office_Ellie                   NaN  Commercial Property             NaN
# Office_Cristina                NaN            Education             NaN
# Office_Jesus                   Gas           Government             Gas
# Office_Erik                    NaN  Commercial Property             NaN
# Office_Evelyn                  NaN  Commercial Property             NaN
# Office_Emer                    NaN  Commercial Property             NaN
# Office_Elena                   NaN  Commercial Property             NaN
# Office_Jett                    Gas           Government             Gas
# Office_Jerry                   Oil           Government             Oil
# Office_Eileen                  NaN  Commercial Property             NaN
# Office_Lesa                    Gas            Education             Gas
# Office_Emerald                 NaN  Commercial Property             NaN
# Office_Ellis                   NaN  Commercial Property             NaN
# Office_Elliot                  NaN  Commercial Property             NaN
# Office_Eddie                   NaN  Commercial Property             NaN
# Office_Jackie                  Gas           Government             Gas
# Office_Marla                   NaN            Education             NaN
# Office_Maryann                 NaN            Education             NaN
# Office_Myron                   NaN            Education             NaN
# Office_Conrad                  NaN            Education             NaN
# Office_Mick                    NaN            Education             NaN
# Office_Jayden                  Gas           Government             Gas
# Office_Moises                  NaN            Education             NaN
# Office_Tod                     NaN            Education             NaN
# Office_Marcus                  NaN            Education             NaN
# Office_Bobbi                   NaN            Education             NaN
# Office_Georgia    District Heating           Government             NaN
# Office_Skyler                  NaN            Education             NaN
# Office_Marc                    NaN            Education             NaN
# ...                            ...                  ...             ...
# Office_Aliyah                  NaN            Education             NaN
# Office_Curt                    NaN            Education             NaN
# Office_Glenn           Electricity           Government     Electricity
# Office_Terrell                 NaN            Education             NaN
# Office_Leland                  Gas            Education             Gas
# Office_Mikayla                 NaN            Education             NaN
# Office_Ayden                   NaN            Education             NaN
# Office_Colby                   NaN            Education             NaN
# Office_Carissa                 NaN            Education             NaN
# Office_Paula                   NaN            Education             NaN
# Office_Ashanti                 NaN            Education             NaN
# Office_Garman                  Gas           Government             Gas
# Office_Cora                    NaN            Education             NaN
# Office_Mason                   NaN            Education             NaN
# Office_Clinton                 NaN            Education             NaN
# Office_Paulette                NaN            Education             NaN
# Office_Dawn                    NaN            Education             NaN
# Office_Perla                   NaN            Education             NaN
# Office_Precious                NaN            Education             NaN
# Office_Patricia                NaN            Education             NaN
# Office_Pasquale                NaN            Education             NaN
# Office_Bryon                   NaN            Education             NaN
# Office_Marcia                  NaN            Education             NaN
# Office_Dorian                  NaN            Education             NaN
# Office_Shelly                  NaN            Education             NaN
# Office_Pauline                 NaN            Education             NaN
# Office_Luann                   Gas            Education             Gas
# Office_Milton                  NaN            Education             NaN
# Office_Lane           Heat network            Education    Heat Network
# Office_Cameron                 NaN            Education             NaN
#
#                   numberoffloors  occupants primaryspaceusage rating  \
# uid
# Office_Elizabeth             NaN        NaN            Office    NaN
# Office_Ellie                 NaN        NaN            Office    NaN
# Office_Cristina              NaN        NaN            Office    NaN
# Office_Jesus                 1.0       40.0            Office      C
# Office_Erik                  NaN        NaN            Office    NaN
# Office_Evelyn                NaN        NaN            Office    NaN
# Office_Emer                  NaN        NaN            Office    NaN
# Office_Elena                 NaN        NaN            Office    NaN
# Office_Jett                  2.0        NaN            Office    NaN
# Office_Jerry                 2.0        0.0            Office      C
# Office_Eileen                NaN        NaN            Office    NaN
# Office_Lesa                  6.0        NaN            Office    NaN
# Office_Emerald               NaN        NaN            Office    NaN
# Office_Ellis                 NaN        NaN            Office    NaN
# Office_Elliot                NaN        NaN            Office    NaN
# Office_Eddie                 NaN        NaN            Office    NaN
# Office_Jackie                2.0        NaN            Office    NaN
# Office_Marla                 NaN        NaN            Office    NaN
# Office_Maryann               NaN        NaN            Office    NaN
# Office_Myron                 NaN        NaN            Office    NaN
# Office_Conrad                NaN        NaN            Office    NaN
# Office_Mick                  NaN        NaN            Office    NaN
# Office_Jayden                1.0       12.0            Office      G
# Office_Moises                NaN        NaN            Office    NaN
# Office_Tod                   NaN        NaN            Office    NaN
# Office_Marcus                NaN        NaN            Office    NaN
# Office_Bobbi                 NaN        NaN            Office    NaN
# Office_Georgia               7.0      188.0            Office      C
# Office_Skyler                NaN        NaN            Office      C
# Office_Marc                  NaN        NaN            Office    NaN
# ...                          ...        ...               ...    ...
# Office_Aliyah                NaN        NaN            Office    NaN
# Office_Curt                  NaN        NaN            Office    NaN
# Office_Glenn                 7.0       97.0            Office      F
# Office_Terrell               NaN        NaN            Office    NaN
# Office_Leland                8.0        NaN            Office      D
# Office_Mikayla               NaN        NaN            Office    NaN
# Office_Ayden                 NaN        NaN            Office    NaN
# Office_Colby                 NaN        NaN            Office    NaN
# Office_Carissa               NaN        NaN            Office    NaN
# Office_Paula                 NaN        NaN            Office    NaN
# Office_Ashanti               NaN        NaN            Office    NaN
# Office_Garman               10.0      818.0            Office      E
# Office_Cora                  NaN        NaN            Office    NaN
# Office_Mason                 NaN        NaN            Office    NaN
# Office_Clinton               NaN        NaN            Office    NaN
# Office_Paulette              NaN        NaN            Office    NaN
# Office_Dawn                  NaN        NaN            Office    NaN
# Office_Perla                 NaN        NaN            Office    NaN
# Office_Precious              NaN        NaN            Office    NaN
# Office_Patricia              NaN        NaN            Office    NaN
# Office_Pasquale              NaN        NaN            Office    NaN
# Office_Bryon                 NaN        NaN            Office    NaN
# Office_Marcia                NaN        NaN            Office    NaN
# Office_Dorian                NaN        NaN            Office    NaN
# Office_Shelly                NaN        NaN            Office      C
# Office_Pauline               NaN        NaN            Office    NaN
# Office_Luann                 8.0        NaN            Office      E
# Office_Milton                NaN        NaN            Office    NaN
# Office_Lane                  8.0        NaN            Office    NaN
# Office_Cameron               NaN        NaN            Office    NaN
#
#                           sqft            sqm                 subindustry  \
# uid
# Office_Elizabeth  2.946510e+05   27373.961850      Commercial Real Estate
# Office_Ellie      4.965170e+05   46127.918850     Bank/Financial Services
# Office_Cristina   9.227100e+04    8572.252713          College/University
# Office_Jesus      4.264657e+04    3962.000000         City, County, State
# Office_Erik       1.262050e+05   11724.823120           Business Services
# Office_Evelyn     1.675720e+06  155679.415200           Business Services
# Office_Emer       1.915540e+05   17795.941260            Corporate Office
# Office_Elena      1.694200e+05   15739.626260            Corporate Office
# Office_Jett       7.879175e+03     732.000000         City, County, State
# Office_Jerry      1.659793e+04    1542.000000         City, County, State
# Office_Eileen     3.181300e+05   29555.231390     Bank/Financial Services
# Office_Lesa       4.772713e+04    4434.000000          College/University
# Office_Emerald    4.762460e+05   44244.682140      Commercial Real Estate
# Office_Ellis      4.282770e+05   39788.218130      Commercial Real Estate
# Office_Elliot     1.858470e+05   17265.743840      Commercial Real Estate
# Office_Eddie      1.796650e+05   16691.417500           Business Services
# Office_Jackie     1.220626e+04    1134.000000         City, County, State
# Office_Marla      3.340100e+04    3103.053103          College/University
# Office_Maryann    2.086400e+04    1938.328192          College/University
# Office_Myron      9.299400e+04    8639.421582          College/University
# Office_Conrad     2.161800e+04    2008.377054          College/University
# Office_Mick       8.436500e+04    7837.761595          College/University
# Office_Jayden     1.187258e+04    1103.000000         City, County, State
# Office_Moises     3.709600e+04    3446.329688          College/University
# Office_Tod        1.810380e+04    1681.900000          College/University
# Office_Marcus     7.270900e+04    6754.884227          College/University
# Office_Bobbi      1.372970e+05   12755.303190          College/University
# Office_Georgia    3.396010e+04    3155.000000  Other Government Buildings
# Office_Skyler     1.698543e+04    1578.000000          College/University
# Office_Marc       4.757800e+04    4420.138934          College/University
# ...                        ...            ...                         ...
# Office_Aliyah     2.024350e+05   18806.818810          College/University
# Office_Curt       1.579330e+05   14672.449500          College/University
# Office_Glenn      1.850314e+04    1719.000000  Other Government Buildings
# Office_Terrell    1.776582e+04    1650.500000          College/University
# Office_Leland     3.049521e+04    2833.100000          College/University
# Office_Mikayla    1.021910e+05    9493.850473          College/University
# Office_Ayden      7.083200e+04    6580.505296          College/University
# Office_Colby      1.103800e+05   10254.633140          College/University
# Office_Carissa    4.955300e+04    4603.622359          College/University
# Office_Paula      4.433200e+04    4118.575796          College/University
# Office_Ashanti    7.083700e+04    6580.969811          College/University
# Office_Garman     1.506408e+05   13995.000000  Other Government Buildings
# Office_Cora       4.275500e+04    3972.067765          College/University
# Office_Mason      3.838200e+04    3565.802946          College/University
# Office_Clinton    4.698100e+04    4364.675843          College/University
# Office_Paulette   2.345800e+04    2179.318574          College/University
# Office_Dawn       8.332100e+04    7740.770863          College/University
# Office_Perla      5.459700e+04    5072.225091          College/University
# Office_Precious   7.004200e+04    6507.111926          College/University
# Office_Patricia   4.999000e+04    4644.220970          College/University
# Office_Pasquale   1.787900e+04    1661.012737          College/University
# Office_Bryon      9.761800e+04    9069.005054          College/University
# Office_Marcia     6.283700e+04    5837.745811          College/University
# Office_Dorian     1.110770e+05   10319.386530          College/University
# Office_Shelly     1.581217e+04    1469.000000          College/University
# Office_Pauline    4.133700e+04    3840.331311          College/University
# Office_Luann      6.565656e+04    6099.700000          College/University
# Office_Milton     1.051670e+05    9770.329801          College/University
# Office_Lane       3.445524e+04    3201.000000          College/University
# Office_Cameron    5.330300e+04    4952.008609          College/University
#
#                              timezone  yearbuilt   nickname  \
# uid
# Office_Elizabeth  America/Los_Angeles        NaN  Elizabeth
# Office_Ellie      America/Los_Angeles        NaN      Ellie
# Office_Cristina      America/New_York       2001   Cristina
# Office_Jesus            Europe/London  Post 1976      Jesus
# Office_Erik          America/New_York        NaN       Erik
# Office_Evelyn     America/Los_Angeles        NaN     Evelyn
# Office_Emer          America/New_York        NaN       Emer
# Office_Elena         America/New_York        NaN      Elena
# Office_Jett             Europe/London   pre 1919       Jett
# Office_Jerry            Europe/London  Post 1976      Jerry
# Office_Eileen     America/Los_Angeles        NaN     Eileen
# Office_Lesa             Europe/London       1928       Lesa
# Office_Emerald       America/New_York        NaN    Emerald
# Office_Ellis         America/New_York        NaN      Ellis
# Office_Elliot        America/New_York        NaN     Elliot
# Office_Eddie         America/New_York        NaN      Eddie
# Office_Jackie           Europe/London  post 1976     Jackie
# Office_Marla          America/Chicago        NaN      Marla
# Office_Maryann        America/Chicago        NaN    Maryann
# Office_Myron          America/Chicago        NaN      Myron
# Office_Conrad        America/New_York       1887     Conrad
# Office_Mick           America/Chicago        NaN       Mick
# Office_Jayden           Europe/London  1945-1966     Jayden
# Office_Moises         America/Chicago        NaN     Moises
# Office_Tod              Europe/Zurich        NaN        Tod
# Office_Marcus         America/Chicago        NaN     Marcus
# Office_Bobbi      America/Los_Angeles       1917      Bobbi
# Office_Georgia          Europe/London       1900    Georgia
# Office_Skyler           Europe/London       1978     Skyler
# Office_Marc           America/Chicago        NaN       Marc
# ...                               ...        ...        ...
# Office_Aliyah         America/Phoenix       1967     Aliyah
# Office_Curt          America/New_York       1932       Curt
# Office_Glenn            Europe/London       1937      Glenn
# Office_Terrell          Europe/Zurich        NaN    Terrell
# Office_Leland           Europe/London       1997     Leland
# Office_Mikayla        America/Chicago        NaN    Mikayla
# Office_Ayden          America/Phoenix       2014      Ayden
# Office_Colby         America/New_York       1985      Colby
# Office_Carissa       America/New_York       1963    Carissa
# Office_Paula         America/New_York        NaN      Paula
# Office_Ashanti        America/Phoenix       2014    Ashanti
# Office_Garman           Europe/London  1913-1915     Garman
# Office_Cora          America/New_York       1866       Cora
# Office_Mason          America/Chicago        NaN      Mason
# Office_Clinton       America/New_York       1962    Clinton
# Office_Paulette      America/New_York        NaN   Paulette
# Office_Dawn       America/Los_Angeles       1960       Dawn
# Office_Perla         America/New_York        NaN      Perla
# Office_Precious      America/New_York        NaN   Precious
# Office_Patricia      America/New_York        NaN   Patricia
# Office_Pasquale      America/New_York        NaN   Pasquale
# Office_Bryon      America/Los_Angeles       1964      Bryon
# Office_Marcia         America/Chicago        NaN     Marcia
# Office_Dorian     America/Los_Angeles       1994     Dorian
# Office_Shelly           Europe/London        NaN     Shelly
# Office_Pauline       America/New_York        NaN    Pauline
# Office_Luann            Europe/London       1955      Luann
# Office_Milton         America/Chicago        NaN     Milton
# Office_Lane             Europe/London       1907       Lane
# Office_Cameron       America/New_York       1981    Cameron
#
#                  primaryspaceuse_abbrev newweatherfilename
# uid
# Office_Elizabeth                 Office      weather22.csv
# Office_Ellie                     Office      weather28.csv
# Office_Cristina                  Office       weather2.csv
# Office_Jesus                     Office       weather1.csv
# Office_Erik                      Office      weather14.csv
# Office_Evelyn                    Office      weather20.csv
# Office_Emer                      Office      weather36.csv
# Office_Elena                     Office      weather37.csv
# Office_Jett                      Office       weather1.csv
# Office_Jerry                     Office       weather1.csv
# Office_Eileen                    Office      weather27.csv
# Office_Lesa                      Office       weather5.csv
# Office_Emerald                   Office      weather16.csv
# Office_Ellis                     Office      weather25.csv
# Office_Elliot                    Office      weather31.csv
# Office_Eddie                     Office      weather30.csv
# Office_Jackie                    Office       weather1.csv
# Office_Marla                     Office       weather3.csv
# Office_Maryann                   Office       weather3.csv
# Office_Myron                     Office       weather3.csv
# Office_Conrad                    Office       weather2.csv
# Office_Mick                      Office       weather3.csv
# Office_Jayden                    Office       weather1.csv
# Office_Moises                    Office       weather3.csv
# Office_Tod                       Office       weather8.csv
# Office_Marcus                    Office       weather3.csv
# Office_Bobbi                     Office       weather7.csv
# Office_Georgia                   Office       weather5.csv
# Office_Skyler                    Office       weather6.csv
# Office_Marc                      Office       weather3.csv
# ...                                 ...                ...
# Office_Aliyah                    Office       weather0.csv
# Office_Curt                      Office       weather2.csv
# Office_Glenn                     Office       weather5.csv
# Office_Terrell                   Office       weather8.csv
# Office_Leland                    Office       weather5.csv
# Office_Mikayla                   Office       weather3.csv
# Office_Ayden                     Office       weather0.csv
# Office_Colby                     Office       weather2.csv
# Office_Carissa                   Office       weather2.csv
# Office_Paula                     Office       weather4.csv
# Office_Ashanti                   Office       weather0.csv
# Office_Garman                    Office       weather5.csv
# Office_Cora                      Office       weather2.csv
# Office_Mason                     Office       weather3.csv
# Office_Clinton                   Office       weather2.csv
# Office_Paulette                  Office       weather4.csv
# Office_Dawn                      Office      weather13.csv
# Office_Perla                     Office       weather4.csv
# Office_Precious                  Office       weather4.csv
# Office_Patricia                  Office       weather4.csv
# Office_Pasquale                  Office       weather4.csv
# Office_Bryon                     Office       weather7.csv
# Office_Marcia                    Office       weather3.csv
# Office_Dorian                    Office      weather13.csv
# Office_Shelly                    Office       weather6.csv
# Office_Pauline                   Office       weather4.csv
# Office_Luann                     Office       weather5.csv
# Office_Milton                    Office       weather3.csv
# Office_Lane                      Office       weather5.csv
# Office_Cameron                   Office       weather2.csv
#
# [156 rows x 18 columns]

# %%
building = "Office_Phebian"

# %%
meta.T[building].timezone
# Out:
# 'America/New_York'

# %%
spearman = createspearman(temp, meta, building)

# %%
#spearman

# %%
def get_individual_data(temp, meta, building):
    timezone = meta.T[building].timezone
    start = meta.T[building].datastart
    end = meta.T[building].dataend
    return pd.DataFrame(temp[building].tz_convert(timezone).truncate(before=start,after=end))

def get_individual_data_notz(temp, meta, building):
    start = meta.T[building].datastart
    end = meta.T[building].dataend
    return pd.DataFrame(temp[building].truncate(before=start,after=end))

# %%
def plot_line_example(df_1, df_2,  color):
    sns.set(rc={"figure.figsize": (8,4)})
    sns.set_style('whitegrid')
    fig = plt.figure()
    fig.autofmt_xdate()
    fig.subplots_adjust(hspace=.5)
    gs = GridSpec(100,100,bottom=0.18,left=0.18,right=0.88)
    
    df_1.columns = ["Actual kWh"]
    #df_predicted.columns = ["Predicted kWh"]
    ax1 = fig.add_subplot(gs[1:60,:])
    df_1.plot(ax = ax1, legend=False)
    ax1.xaxis.set_visible(False)
    ax1.set_title("Hourly kWh")
    
    ax2 = fig.add_subplot(gs[68:,:])
    df_2 = df_2.tz_localize(None)
    x = mdates.drange(df_2.index[0], df_2.index[-1] + datetime.timedelta(days=1), datetime.timedelta(days=1))
    y = np.linspace(0, len(df_2.columns), len(df_2.columns)+1)
    data = np.array(df_2.T)
    datam = np.ma.array(data, mask=np.isnan(data))
    cmap = matplotlib.cm.get_cmap(color)
    qmesh = ax2.pcolormesh(x, y, datam, cmap=cmap)
    ax2.set_title("Montly Spearman Rank Order Correlation Coefficient")
    
    #leftspacing, 
    cbaxes = fig.add_axes([0.18, 0.08, 0.7, 0.02]) 
    cbar = fig.colorbar(qmesh, ax=ax2, orientation='horizontal', cax=cbaxes)
    
    ax2.axis('tight')
    ax2.xaxis_date()
    ax2.yaxis.set_visible(False)
    myFmt = mdates.DateFormatter('%b %d')
    ax2.xaxis.set_major_formatter(myFmt)

# %%
df = get_individual_data(temp, meta, building)#
#df = df.resample('D').sum().tz_localize(None)

# %%
plot_line_example(df, spearman, "RdBu")
plt.savefig(os.path.join(repos_path,"reports/figures/featureoverviews/spearman_example.pdf"));

# %%
#sns.palplot(sns.light_palette("viridis"))

# %% [markdown]
# # Loop though all buildings

# %%
spearmans = pd.DataFrame()
for building in meta.index:
    spearman = createspearman(temp, meta, building)
    spearmans = pd.merge(spearmans, spearman, right_index=True, left_index=True, how='outer')

# %%
spearmans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1616 entries, 2010-01-01 to 2015-12-01
# Columns: 507 entries, PrimClass_Everett to UnivLab_Aoife
# dtypes: float64(507)
# memory usage: 6.3 MB

# %% [markdown]
# # Overview heatmap

# %%
def heatmap_data(df):
    x = mdates.drange(df.index[0], df.index[-1] + datetime.timedelta(days=1), datetime.timedelta(days=1))
    y = np.linspace(0, len(df.columns), len(df.columns)+1)
    return x,y

#This function changes the year for all of the buildings so that they can be overlapped for plotting
# THE RESULTING DATAFRAME IS ONLY FOR "GENERALIZED" PLOTTING TO GET THE DATA SETS TO OVERLAP -- DON'T PERFORM CALCULATIONS ON IT

def changeto2015(x):
    try:
        return x.replace(year=2015)
    except:
        return np.nan
    
def is_leap_and_29Feb(s):
    return (s.index.year % 4 == 0) & ((s.index.year % 100 != 0) | (s.index.year % 400 == 0)) & (s.index.month == 2) & (s.index.day == 29)

def generalize_timestamp_forplotting(meta, temp):
    temp_generalized = pd.DataFrame()
    buildinglist = list(meta.index)
    
    for building in buildinglist:
        #Change to timezone
        timezone = meta.T[building].timezone
        start = meta.T[building].datastart
        end = meta.T[building].dataend
        building_data = pd.DataFrame(temp[building].tz_convert(timezone).truncate(before=start,after=end))
        
        #Remove leap year day for 2012
        mask = is_leap_and_29Feb(building_data)
        building_data = building_data.loc[~mask]
        
        #Change to 2015 -- we arbitrarily use this year
        building_data.index = building_data.index.map(lambda t: changeto2015(t))
        
        #Remove tz awareness, resample to normalize the timestamps and ffill to get rid of the gaps
        building_data = building_data.tz_localize(None)
        building_data = building_data.resample('D').mean().sort_index()
        building_data = building_data.ffill()
        
        #Merge into dataset
        temp_generalized = pd.merge(temp_generalized, building_data, right_index=True, left_index=True, how='outer')
        temp_generalized = temp_generalized.resample('D').mean().sort_index()
        
        #print "finished building: "+building
    return temp_generalized

def generalize_timestamp_forplotting_notz(meta, temp):
    temp_generalized = pd.DataFrame()
    buildinglist = list(meta.index)
    
    for building in buildinglist:
        #Change to timezone
        start = meta.T[building].datastart
        end = meta.T[building].dataend
        building_data = pd.DataFrame(temp[building].truncate(before=start,after=end))
        
        #Remove leap year day for 2012
        mask = is_leap_and_29Feb(building_data)
        building_data = building_data.loc[~mask]
        
        #Change to 2015 -- we arbitrarily use this year
        building_data.index = building_data.index.map(lambda t: changeto2015(t))
        
        #Remove tz awareness, resample to normalize the timestamps and ffill to get rid of the gaps
        building_data = building_data.tz_localize(None)
        building_data = building_data.resample('D').mean().sort_index()
        building_data = building_data.ffill()
        
        #Merge into dataset
        temp_generalized = pd.merge(temp_generalized, building_data, right_index=True, left_index=True, how='outer')
        temp_generalized = temp_generalized.resample('D').mean().sort_index()
        
        #print "finished building: "+building
    return temp_generalized

def plotmap(df, color, cbarlabel, xaxislabel, yaxislabel, graphiclabel, filelabel):
    
    import matplotlib.dates as mdates
    from matplotlib import ticker
    import datetime
    import matplotlib
    import seaborn as sns

    # Set up the size/style
    sns.set(rc={"figure.figsize": (5,12)})
    sns.set_style("whitegrid")
    
    numberofplots = 1
    fig = plt.figure()
    
    x = mdates.drange(df.index[0], df.index[-1] + datetime.timedelta(days=1), datetime.timedelta(days=1))
    y = np.linspace(0, len(df.columns), len(df.columns)+1)
    ax = fig.add_subplot(numberofplots, 1, 1)
    data = np.array(df.T)
    datam = np.ma.array(data, mask=np.isnan(data))
    cmap = matplotlib.cm.get_cmap(color)
    qmesh = ax.pcolormesh(x, y, datam, cmap=cmap)
    
    cbaxes = fig.add_axes([0.15, 0.15, 0.7, 0.02]) 
    cbar = fig.colorbar(qmesh, ax=ax, orientation='horizontal', cax=cbaxes)
    
    cbar.ax.tick_params(length = 0)
    cbar.set_label(cbarlabel)
    
    ax.axis('tight')
    ax.xaxis_date()
    fig.autofmt_xdate()
    fig.subplots_adjust(hspace=.5)
    ax.set_xlabel(xaxislabel)
    ax.set_ylabel(yaxislabel)
    ax.set_title(graphiclabel)
    
    ax.set_yticklabels(df.columns)
    tick_locator = ticker.MaxNLocator(nbins=110)
    loc = ticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
    ax.locator_params(axis='y', nbins=100)
    myFmt = mdates.DateFormatter('%b')
    ax.xaxis.set_major_formatter(myFmt)
    
    plt.subplots_adjust(bottom=0.2)

def plotmap_subplots(df, meta, color, cbarlabel, xaxislabel, yaxislabel, graphiclabel, filelabel, z_min, z_max):

    import matplotlib.dates as mdates
    from matplotlib import ticker
    import datetime
    import matplotlib
    import seaborn as sns

    # Set up the size/style
    sns.set(rc={"figure.figsize": (5,12)})
    sns.set_style("whitegrid")
    cmap = matplotlib.cm.get_cmap(color)
    
    fig = plt.figure()
    fig.autofmt_xdate()
    fig.subplots_adjust(hspace=.5)
    gs = GridSpec(100,100,bottom=0.18,left=0.18,right=0.88)
    
    # Plot Offices
    df_office = df[df.columns[df.columns.str.contains("Office")]]
    office_height = int(len(df_office.T)/len(df.T)*100-2)
    ax1 = fig.add_subplot(gs[1:office_height,:])
    x,y = heatmap_data(df_office)
    data = np.array(df_office.T)
    datam = np.ma.array(data, mask=np.isnan(df_office))
    qmesh = ax1.pcolormesh(x, y, datam, cmap=cmap, vmin=z_min, vmax=z_max)
    ax1.axis('tight')
    ax1.xaxis_date()
#     ax1.set_title("Offices")
    ax1.xaxis.set_visible(False)
    
    # Plot UnivLab
    df_lab = df[df.columns[df.columns.str.contains("UnivLab")]]
    lab_height = int(len(df_lab.T)/len(df.T)*100-2)
    ax2 = fig.add_subplot(gs[office_height+2:office_height+lab_height,:])
    x,y = heatmap_data(df_lab)
    data = np.array(df_lab.T)
    datam = np.ma.array(data, mask=np.isnan(df_lab))
    qmesh = ax2.pcolormesh(x, y, datam, cmap=cmap, vmin=z_min, vmax=z_max)
    ax2.axis('tight')
    ax2.xaxis_date()
#     ax2.set_title("University Labs")
    ax2.xaxis.set_visible(False)
    
    # Plot UnivClass
    df_uniclass = df[df.columns[df.columns.str.contains("UnivClass")]]
    uniclass_height = int(len(df_uniclass.T)/len(df.T)*100-2)
    ax3 = fig.add_subplot(gs[office_height+lab_height+2:office_height+lab_height+uniclass_height,:])
    x,y = heatmap_data(df_uniclass)
    data = np.array(df_uniclass.T)
    datam = np.ma.array(data, mask=np.isnan(df_uniclass))
    qmesh = ax3.pcolormesh(x, y, datam, cmap=cmap, vmin=z_min, vmax=z_max)
    ax3.axis('tight')
    ax3.xaxis_date()
#     ax3.set_title("University Classrooms")
    ax3.xaxis.set_visible(False)

    # Plot PrimClass
    df_primclass = df[df.columns[df.columns.str.contains("PrimClass")]]
    primclass_height = int(len(df_primclass.T)/len(df.T)*100-2)
    ax4 = fig.add_subplot(gs[office_height+lab_height+uniclass_height+2:office_height+lab_height+uniclass_height+primclass_height,:])
    x,y = heatmap_data(df_primclass)
    data = np.array(df_primclass.T)
    datam = np.ma.array(data, mask=np.isnan(df_primclass))
    qmesh = ax4.pcolormesh(x, y, datam, cmap=cmap, vmin=z_min, vmax=z_max)
    ax4.axis('tight')
    ax4.xaxis_date()
#     ax4.set_title("Primary/Secondary Classroom")
    ax4.xaxis.set_visible(False)

    
    # Plot Univ Dorms
    df_unidorm = df[df.columns[df.columns.str.contains("UnivDorm")]]
    unidorm_height = int(len(df_unidorm.T)/len(df.T)*100-2)
    ax5 = fig.add_subplot(gs[office_height+lab_height+uniclass_height+primclass_height+2:office_height+lab_height+uniclass_height+primclass_height+unidorm_height,:])
    x,y = heatmap_data(df_unidorm)
    data = np.array(df_unidorm.T)
    datam = np.ma.array(data, mask=np.isnan(df_unidorm))
    qmesh = ax5.pcolormesh(x, y, datam, cmap=cmap, vmin=z_min, vmax=z_max)
    ax5.axis('tight')
    ax5.xaxis_date()
#     ax5.set_title("University Dorms")
    
    cbaxes = fig.add_axes([0.18, 0.23, 0.7, 0.02]) 
    cbar = fig.colorbar(qmesh, orientation='horizontal', cax=cbaxes) #ax=ax,
    
    cbar.ax.tick_params(length = 0)
    cbar.set_label(cbarlabel)

    myFmt = mdates.DateFormatter('%b')
    ax5.xaxis.set_major_formatter(myFmt)
    
    fig.text(0.14, 0.5, yaxislabel, va='center', rotation='vertical')

# %%
temp_spearman_generalized = generalize_timestamp_forplotting_notz(meta, spearmans).ffill().bfill()

# %%
temp_spearman_generalized_sorted = temp_spearman_generalized[list(temp_spearman_generalized.sum().sort_values().index)]

# %%
plotmap_subplots(temp_spearman_generalized_sorted, meta, 'RdBu', "Monthly Spearman Rank Order Correlation Coefficient",
                 " ", "", " ", "Monthly Spearman Rank Order Correlation Coefficient", -1, 1)
plt.savefig(os.path.join(repos_path,"reports/figures/featureoverviews/spearman_heatmap.pdf"));

# %%
#temp_spearman_generalized.describe(include="all")

# %%
#from pandas_summary import DataFrameSummary

# %%
#dfs = DataFrameSummary(temp_spearman_generalized)

# %%
#building

# %%
#dfs[building]["top_correlations"]
